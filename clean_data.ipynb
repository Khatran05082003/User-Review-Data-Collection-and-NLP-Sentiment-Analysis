# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df = pd.read_csv("reviews.csv", index_col=0)
df.head(10)
# Out:
#                                              reviews  \
# 0  Facebook full of romance scams, vehicle scams,...
# 1  FB Marketplace a scammers paradise.I'd say mor...
# 2  Absolutely rubbish they encourage you to repor...
# 3  1 star is too generous. My Facebook account ac...
# 4  Facebook has let someone hack a dead man's acc...
# 5  Facebook account got hacked and I can no longe...
# 6  One of the things I love most about Facebook i...
# 7  FB MARKETPLACE FULL OF SCAMMERS.YOU REPORT SCA...
# 8  Community guidelines are total mess. Works for...
# 9  Wish there was a no star selection!! My Facebo...
#
#                        date  stars
# 0  2023-11-12T17:26:52.000Z      1
# 1  2023-11-10T17:31:57.000Z      1
# 2  2023-11-11T10:29:43.000Z      1
# 3  2023-11-12T00:07:17.000Z      1
# 4  2023-11-12T22:15:26.000Z      1
# 5  2023-11-11T10:30:33.000Z      1
# 6  2023-11-08T12:17:29.000Z      5
# 7  2023-11-10T22:24:52.000Z      1
# 8  2023-11-13T03:59:36.000Z      1
# ...

# %%
df['date'] = pd.to_datetime(df['date']).apply(lambda x: x.strftime('%Y-%m-%d'))

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
lemma = WordNetLemmatizer()

# %%
corpus =[]


for rev in df['reviews']:
    rev = re.sub('[^a-zA-Z0-9]',' ', str(rev))
    rev = rev.lower()
    rev = rev.split()
    rev = [lemma.lemmatize(word) for word in rev if word not in set(stopwords.words("english"))]
    rev = " ".join(rev)
    corpus.append(rev)

# %%
df['corpus']=corpus

# %%
df['date'] = pd.to_datetime(df['date']).apply(lambda x: x.strftime('%Y-%m-%d'))

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# reviews            object
# date       datetime64[ns]
# stars               int64
# corpus             object
# dtype: object

# %%
df['stars'].value_counts()
# Out:
# 1    1648
# 5     161
# 2      68
# 4      67
# 3      56
# Name: stars, dtype: int64

# %%
df.isna().sum()
# Out:
# reviews    156
# date         0
# stars        0
# corpus       0
# dtype: int64

# %%
df.drop(df[df['reviews'].isnull() == True].index, axis=0, inplace=True)

# %%
df.isna().sum()
# Out:
# reviews    0
# date       0
# stars      0
# corpus     0
# dtype: int64

# %%
df.shape
# Out:
# (1844, 4)

# %%
df.reset_index(drop=True)
# Out:
#                                                 reviews       date  stars  \
# 0     Facebook full of romance scams, vehicle scams,... 2023-11-12      1
# 1     FB Marketplace a scammers paradise.I'd say mor... 2023-11-10      1
# 2     Absolutely rubbish they encourage you to repor... 2023-11-11      1
# 3     1 star is too generous. My Facebook account ac... 2023-11-12      1
# 4     Facebook has let someone hack a dead man's acc... 2023-11-12      1
# ...                                                 ...        ...    ...
# 1839  Thoroughly recommended, quick and efficient, m... 2022-01-22      5
# 1840  Facebook allows Fake & "Alias" accounts for pe... 2022-01-22      1
# 1841  Poor standards and support. Reported video whe... 2022-01-22      1
# 1842  This is nothing less than the world's biggest ... 2022-01-22      1
# 1843  There is some good, some bad here. For marketi... 2022-01-21      3
#
#                                                  corpus
# ...

# %%
df.to_csv("cleaned-BA-reviews.csv")
